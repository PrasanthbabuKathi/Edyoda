# %% [markdown]
# You have to design a Food Ordering app for a restaurant.
#
#
#
# The application will have a log-in for admin and users.
#
#
#
# Admin will have the following functionalities:
#
# Add new food items. Food Item will have the following details:
# FoodID //It should be generated automatically by the application.
# Name
# Quantity. For eg, 100ml, 250gm, 4pieces etc
# Price
# Discount
# Stock. Amount left in stock in the restaurant.
# Edit food items using FoodID.
# View the list of all food items.
# Remove a food item from the menu using FoodID.
#
#
#
#
# The user will have the following functionalities:
#
# Register on the application. Following to be entered for registration:
# Full Name
# Phone Number
# Email
# Address
# Password
# Log in to the application
# The user will see 3 options:
# Place New Order
# Order History
# Update Profile
# Place New Order: The user can place a new order at the restaurant.
# Show list of food. The list item should as follows:
# 1. Tandoori Chicken (4 pieces) [INR 240]
# 2. Vegan Burger (1 Piece) [INR 320]
# 3. Truffle Cake (500gm) [INR 900]
# Users should be able to select food by entering an array of numbers. For example, if the user wants to order Vegan Burger and Truffle Cake they should enter [2, 3]
# Once the items are selected user should see the list of all the items selected. The user will also get an option to place an order.
# Order History should show a list of all the previous orders
# Update Profile: the user should be able to update their profile.

# %%
import json, datetime
from json import JSONDecodeError

def register(type, name, phone_number, email_id, password, address):
    f=open('accounts.json','r+')
    d ={
        'Type':type,
        'Name':name,
        'Phone number':phone_number,
        'Email ID':email_id,
        'Password':password,
        'Address':address
    }
    
    try:
        content = json.load(f)
        drd = False
        for i in content:
            if i['Phone number'] == phone_number:
                drd = True
                
        if drd == False:
            content.append(d)
            f.seek(0)
            f.truncate()
            json.dump(content,f)
            f.close()
            return True
        else:
            print('You are already here')
    except JSONDecodeError:
        l=[]
        l.append(d)
        json.dump(l,f)
        f.close()
        return True
    
    
    
def logging(phone_number,password):
    f = open('accounts.json','r+')
    content = json.load(f)
    
    src = []
    for i in content:
        if i['Phone number'] == phone_number and i['Password'] == password:
            src.append(True)
    
    if True in src:
        return True
    else:
        print('Your creditionals are wrong')
        return False
    f.close()
        
        
        
    
def add_food(name, quantity, price, discount):
    f = open('food.json','r+')
    content = json.load(f)
    
    lst_fd_id = content[-1]['Food-Id']
    fd = lst_fd_id
    tn = fd.split(sep='-')
    tn = tn[1]
    tn = int(tn)+1
    
    fd_id = 'food-'+str(tn)
    
    d ={
        'Food-Id':fd_id,
        'Name':name,
        'Quantity':quantity,
        'Price':price,
        'Discount':discount
    }
    
    try:
        content.append(d)
        print('The computer genarated ID for this food is - ', fd_id)
        print('Succussfully added a new food')
        f.seek(0)
        f.truncate()
        json.dump(content,f)
        f.close()
        return True
    except JSONDecodeError:
        l=[]
        l.append(d)
        json.dump(l,f)
        f.close()
        
        
        
def save_history(phone_number, food_id, name, quantity, book_price, time):
    f=open('accounts.json','r+')
    h ={
        'Food-Id':food_id,
        'Food-Name':name,
        'Quantity':quantity,
        'Total-Price':book_price,
        'Time':time
    }
    
    try:
        content = json.load(f)
        for i in content:
            if i['Phone number'] == phone_number:
                if 'History' not in i:
                    i['History'] = h
                else:
                    i['History'] = (i['History'], h)
            
        f.seek(0)
        f.truncate()
        json.dump(content,f)
        f.close()
        return True
    except JSONDecodeError:
        print('Some thing wrong')

        
        
        ##########################################################################################################
        
        
        
print('------   Welcome to food ordring App   -------')

i1 = 0
while (i1 != 3):
    print('Press: ')
    print('1. Register')
    print('2. Login')
    print('3. Exit')
    
    try:
        i1 = int(input('Enter your choise : '))
    except ValueError:
        print('Your choice is incorrect')
        continue
        
    if i1 == 1:
        reg = 0
        print('Press: ')
        print('1. User')
        print('2. Admin')
        print('3. Exit')
        
        try:
            reg = int(input('Enter your choise'))
        except ValueError:
            print('Your choise is incorrect')
            continue
            
        if reg == 1:
            print('Enter your details to register as a Aser')
            u_ty = 'user'
            u_nm = input('Enter your Name - ')
            u_pn = int(input('Enter your Phone number - '))
            u_em = input('Enter your e-mail address - ')
            u_pw = input('Enter your Password - ')
            u_ad = input('Enter you Address - ')
            
            reg_user = register(u_ty, u_nm, u_pn, u_em, u_pw, u_ad)
            
        elif reg == 2:
            print('Enter your details to register as Admin')
            a_ty = 'admin'
            a_nm = input('Enter your Name - ')
            a_pn = int(input('Enter your Phone number - '))
            a_em = input('Enter your e-mail address - ')
            a_pw = input('Enter your Password - ')
            a_ad = input('Enter you Address - ')
            reg_admin = register(a_ty, a_nm, a_pn, a_em, a_pw, a_ad)
            
        else:
            continue
            
    elif i1 == 2:
        print('Enter your Phone number and Password to login')
        log_pn = int(input('Enter your phone number - '))
        log_pw = input('Enter your password - ')
        
        log_ck = logging(log_pn, log_pw)
            
        if log_ck == False:
            continue
        else:
            print('Yor are logged-in ')
            
            ofa = open('accounts.json')
            cta = json.load(ofa)
            
            of = open('food.json')
            ct = json.load(of)
            
            for i in cta:
                if i['Phone number'] == log_pn:
                    l_ty = i['Type']
                    l_nm = i['Name']
                    l_pn = i['Phone number']
                    l_em = i['Email ID']
                    l_ad = i['Address']
                    l_pw = i['Password']
            
            print('Hi, ', l_nm)
            print('You are ',l_ty.title())
            
            if l_ty.lower() == 'admin':
            
                ai1 = 0
                while (ai1 != 5) :
                    print('Press : ')
                    print('1. Add food item')
                    print('2. View food item by ID')
                    print('3. Edit food item by ID')
                    print('4. Remove food item by ID')
                    print('5. Exite')
                    
                    try:
                        ai1 = int(input('Entery your choice : '))
                    except ValueError:
                        print('Your are choosed wrong choise')
                        continue
                        
                    if ai1 == 1: #Add food item
                        print('-----  Add new item   ------')
                        fd_nm = input('Enter the food name : ')
                        fd_qt = int(input('Enter the adding quantity : '))
                        fd_pr = int(input('Enter the Original price of food : '))
                        fd_ds = int(input('enter the discount for this food item'))
                        
                        ad_fd = add_food(fd_nm, fd_qt, fd_pr, fd_ds)
                        continue
                    elif ai1 == 2: #View food item
                        print('View food item by ID')
                        fd_idv = input('Enter the food ID here, - ')
                        
                        fd_v_ck = False
#                        if fd_idv in ct:
                        for i in ct:
                            if i['Food-Id'] == fd_idv:
                                print('Food ID -  ', i['Food-Id'])
                                print('Name -     ', i['Name'])
                                print('Quantity - ', i['Quantity'])
                                print('Price -    ', i['Price'])
                                print('Discount - ', i['Discount'])
                                fd_v_ck = True
                        of.close()
                        if fd_v_ck == True:
                            continue
                        else:
                            print('Check the food id, whith this id, here is no item')
                            continue
                            
                    elif ai1 == 3: #Edit food item
                        fd_ide = input('Enter the food Id here, - ')
                        
#                        if fd_ide in ct:
                        fd_ed_ck = False
                        for i in ct:
                            if i['Food-Id'] == fd_ide:
                                print('The present data of Food item')
                                print('Food ID -  ', i['Food-Id'])
                                print('Name -     ', i['Name'])
                                print('Quantity - ', i['Quantity'])
                                print('Price -    ', i['Price'])
                                print('Discount - ', i['Discount'])
                                fd_ed_ck = True
                        of.close()
                        if fd_ed_ck == True :
                            print('What do you change')
                            print('1. Name change\n2. Quantity change\n3. Price change\n4. Discount change')
                            
                            try:
                                fd_ed = int(input('Enter the number of the choise'))
                            except ValueError:
                                print('Your choise is unvalid')
                                continue
                                
                            if fd_ed == 1: #Name edit
                                fd_ned = input('Enter the new name - ')
                                for i in ct:
                                    if i['Food-Id'] == fd_ide:
                                        i['Name'] = fd_ned
                                        print('The food item name is changed as ', fd_ned)
                                ofa.close()
                            elif fd_ed == 2: #Quantity edit
                                print('Do you want \n1. Add quantity\n2. Remove quantity')
                                try:
                                    fd_qed = int(input('Enter your choise - '))
                                except ValueError:
                                    print('Your chiose is invalid')
                                    continue
                                if fd_qed == 1: #Adding Quantity
                                    try:
                                        fd_qad = int(input('Enter the quantity that what you want to add - '))
                                    except ValueError:
                                        print('Enter value only')
                                        continue
                                    for i in ct:
                                        if i['Food-Id'] == fd_ide:
                                            i['Quantity'] = i['Quantity'] + fd_qad
                                            print('Now the total Quatnity is ', i['Quantity'])
                                            of.close()
                                            continue
                                            
                                elif fd_qed == 2: #Removing quantity
                                    try:
                                        fd_qre = int(input('Enter the quantity that what you want to Remove - '))
                                    except ValueError:
                                        print('Enter value only')
                                        continue
                                    for i in ct:
                                        if i['Food-Id'] == fd_ide:
                                            i['Quantity'] = i['Quantity'] - fd_qad
                                            print('Now the total Quatnity is ', i['Quantity'])
                                            of.close()
                                            continue
                                else:
                                    continue
                                    
                            elif fd_ed == 3: #Price change
                                fd_ped = int(input('Enter the New price of Food - '))
                                for i in ct:
                                    if i['Food-Id'] == fd_ide:
                                        i['Price'] = fd_ped
                                        print('The food Price is changed as ', fd_ped)
                                of.close()
                            elif fd_ed == 4: #Discount change
                                fd_ded = int(input('Enter the new discount of Food - '))
                                for i in ct:
                                    if i['Food-Id'] == fd_ide:
                                        i['Discount'] = fd_ded
                                        print('The food Discount is changed as ', fd_ded)
                                of.close()
                            else:
                                continue
                        else:
                            print('No item with this food id')
                            continue
                                
                    elif ai1 == 4: #Removing item
                        print('Remove food item by ID')
                        fd_idr = input('Enter the food ID here, - ')
                        
#                            if fd_idr in ct:
                        fd_r_ch = False
                        for i in ct:
                            if i['Food-Id'] == fd_idr:
                                print('Food ID -  ', i['Food-Id'])
                                print('Name -     ', i['Name'])
                                print('Quantity - ', i['Quantity'])
                                print('Price -    ', i['Price'])
                                print('Discount - ', i['Discount'])
                                fd_r_ch = True
                        of.close()
                        if fd_r_ch == True:
                            print("Are you sure,\n1. Remove \n2. Just leav, don'remove")
                            try:
                                fr_rc = int(input('Enter the confirmation '))
                            except ValueError:
                                print('Your chiose is invalid')
                                continue
                            if fr_rc == 1:
                                ind = -1
                                for i in ct:
                                    ind +=1
                                    if i['Food-Id'] == fd_idr:
                                        break
                                ct.pop(ind)
                                of.close()
                                print('The item is delated')
                            else:
                                print('Check the food id, whith this id, here is no item')
                                continue
                                
                                        
                        else:
                            print('Check the food id, whith this id, here is no item')
                            continue
            elif l_ty.lower() == 'user':
        
                ui1 = 0
                while (ui1 != 4):
                    print('Press: ')
                    print('1. Place new order\n2. History\n3. Update your profile\n4. Exit')

                    try:
                        ui1 = int(input('Enter your choise'))
                    except ValueError:
                        print('Your choise is incorrect')
                        continue
                    if ui1 == 1:
                        print('--------    Place a new order    ----------')
                        fd_s_l = 0
                        while (fd_s_l != 4):
                            print('1. Search by ID\n2. Search by Name\n3. Print List of all\n4. Exit')
                            
                            try:
                                fd_s_l = int(input('Enter your choise'))
                            except ValueError:
                                print('Your choise is invalid')
                                continue
                            if fd_s_l == 1:
                                fd_ids = input('Enter the food id here - ')
                                
                                fd_s_r = False
                                for i in ct:
                                    if i['Food-Id'] == fd_ids:
                                        print('The data of Food item')
                                        print('Food ID -  ', i['Food-Id'])
                                        print('Name -     ', i['Name'])
                                        print('Price -    ', i['Price'])
                                        print('Discount - ', i['Discount'])
                                        fd_av_q = i['Quantity']
                                        fd_s_r = True
                                of.close()
                                if fd_s_r != True:
                                    print('With this id, here no food item, please check')
                                    continue
                                else:
                                    print('Would you like to order this item')
                                    print('Press : \n1. Yes, I want book it\n2. No, come to back')
                                    
                                    try:
                                        fd_bk_c = int(input('Enter your choise'))
                                    except ValueError:
                                        print('Your choise is incorrect')
                                        continue
                                    if fd_bk_c == 1:
                                        fd_bk_qa = int(input('Enter how many would you book !'))
                                        if fd_bk_qa > fd_av_q:
                                            print('Your requested quantity is not available, please order the quanty under the avalability')
                                            print('The available Quantity is - ', fd_av_q)
                                        else:
                                            for i in ct:
                                                if i['Food-Id'] == fd_ids:
                                                    i['Quantity'] = i['Quantity'] - fd_bk_qa
                                                    fd_h_q_n = i['Quantity']
                                                    fd_h_s_n = i['Name']
                                                    fd_h_p_n = i['Price']
                                                    fd_h_d_n = i['Discount']
                                                    pht = datetime.datetime.now()
                                                    pht = str(pht)
                                                    cltp = fd_bk_qa*(fd_h_p_n*(fd_h_d_n/100))
                                            of.close()
                                            ofa.close()
                                            cg = save_history(log_pn, fd_ids, fd_h_s_n, fd_h_q_n, cltp, pht)
                                            print('The total amount ordered amount is - ', cltp)
                                            print('Your order is Booked')
                                    elif fd_bk_c == 2:
                                        print('Your are going to previous options')
                                        continue
                                    else:
                                        continue
                            elif fd_s_l == 2:
                                fd_s_kw = input('Enter the keyword or name of the food')
                                fd_nm_r = 0
                                for i in ct:
                                    if fd_s_kw in i['Name']:
                                        fd_nm_r += 1
                                        fd_id_n_s = i['Food-Id']
                                        fd_nm_n_s = i['Name']
                                        fd_pr_n_s = i['Price']
                                        fd_ds_n_s = i['Discount']
                                        fd_qt_n_s = i['Quantity']
                                        print('Food-ID: ', fd_id_n_s, '    Name: ', fd_nm_n_s, '    Price: ',fd_pr_n_s, '    Discount: ',fd_ds_n_s )
                                of.close()
                                if fd_nm_r == 0:
                                    print('with thes keyword or name here is no food items\nPlease search with antother keywork or food name')
                                    continue
                                else:
                                    print('Note the food id what you want')
                                    fd_ids = input('Enter the food id here - ')
                                
                                    fd_s_r = False
                                    for i in ct:
                                        if i['Food-Id'] == fd_ids:
                                            print('The data of Food item')
                                            print('Food ID -  ', i['Food-Id'])
                                            print('Name -     ', i['Name'])
                                            print('Price -    ', i['Price'])
                                            print('Discount - ', i['Discount'])
                                            fd_av_q = i['Quantity']
                                            fd_s_r = True
                                    of.close()
                                    if fd_s_r != True:
                                        print('With this id, here no food item, please check')
                                        continue
                                    else:
                                        print('Would you like to order this item')
                                        print('Press : \n1. Yes, I want book it\n2. No, come to back')
                                    
                                        try:
                                            fd_bk_c = int(input('Enter your choise'))
                                        except ValueError:
                                            print('Your choise is incorrect')
                                            continue
                                    if fd_bk_c == 1:
                                        fd_bk_qa = int(input('Enter how many would you book !'))
                                        if fd_bk_qa > fd_av_q:
                                            print('Your requested quantity is not available, please order the quanty under the avalability')
                                            print('The available Quantity is - ', fd_av_q)
                                        else:
                                            for i in ct:
                                                if i['Food-Id'] == fd_ids:
                                                    i['Quantity'] = i['Quantity'] - fd_bk_qa
                                                    fd_h_q_n = i['Quantity']
                                                    fd_h_s_n = i['Name']
                                                    fd_h_p_n = i['Price']
                                                    fd_h_d_n = i['Discount']
                                                    pht = datetime.datetime.now()
                                                    pht = str(pht)
                                                    cltp = fd_bk_qa*(fd_h_p_n*(fd_h_d_n/100))
                                            of.close()
                                            ofa.close()
                                            cg = save_history(log_pn, fd_ids, fd_h_s_n, fd_h_q_n, cltp, pht)
                                            print('The total amount ordered amount is - ', cltp)
                                            print('Your order is Booked')
                                    elif fd_bk_c == 2:
                                        print('Your are going to previous options')
                                        continue
                                    else:
                                        continue
                            elif fd_s_l == 3:
                                for i in ct:
                                    fd_qt_n_s = i['Quantity']
                                    print('Food-ID: ', i['Food_Id'], '    Name: ', i['Name'], '    Price: ',i['Price'], '    Discount: ',i['Discount'])
                                print('Note down the food ID and serch by ID to book it')
                    elif ui1 == 2:
                        for i in cta:
                            if i['Phone number'] == log_pn:
                                if 'History' in i:
                                    hist = i['History']
                                    for i in hist:
                                        print(i)
                                else:
                                    print("You don't have any history")
                        continue
                    elif ui1 == 3:
                        print('What do you want change !')
                        print('1. Name\n2. e-mail\n3. Password\4. Address')
                        try:
                            uup = int(input('Enter your choice :'))
                        except ValueError:
                            print('Your choise is invalid')
                            continue
                        if upp == 1:
                            unc = input('Enter Your new name')
                            for i in cta:
                                if i['Phone number'] == log_pn:
                                    i['Name'] = unc
                                    print('Your name is updated as - ', unc)
                            ofa.close()
                        elif uup == 2:
                            uec = input('Enter your new email id')
                            for i in cta:
                                if i['Phone number'] == log_pn:
                                    i['Email ID'] = uec
                                    print('Your e-mail is updated as - ',uec)
                            ofa.close()
                        elif uup == 3:
                            upc = input('Enter your new password')
                            for i in cta:
                                if i['Phone number'] == log_pn:
                                    i['Password'] = upc
                                    print('Your password are changed as - ', upc, '\nPlease note the password for further use')
                            ofa.close()
                        elif uup == 4:
                            uac = input('Enter your new Address')
                            for i in cta:
                                if i['Phone Number'] == log_pn:
                                    i['Address'] = uac
                                    print('Your address are upadated as - ', uac)
                            ofa.close()
                        else:
                            print('Your choice is invalid, Please check')
                    elif ui1 == 4:
                        continue
                    else:
                        print('Your choice is invalid')
# Out:
# ------   Welcome to food ordring App   -------
# Press:
# 1. Register
# 2. Login
# 3. Exit
# Enter your choise : 2
# Enter your Phone number and Password to login
# Enter your phone number - 9988776655
# Enter your password - anu12345
# Yor are logged-in
# Hi,  Anusha
# You are  Admin
# Press :
# 1. Add food item
# 2. View food item by ID
# 3. Edit food item by ID
# 4. Remove food item by ID
# 5. Exite
# Entery your choice : 2
# View food item by ID
# Enter the food ID here, - food-3
# Food ID -   food-3
# Name -      Dhum biryani
# Quantity -  100
# Price -     450
# Discount -  25
# Press :
# 1. Add food item
# 2. View food item by ID
# 3. Edit food item by ID
# 4. Remove food item by ID
# 5. Exite
# Entery your choice : 2
# View food item by ID
# Enter the food ID here, - food-4
# Food ID -   food-4
# Name -      Ulava charu biryani
# Quantity -  5
# Price -     500
# Discount -  15
# Press :
# 1. Add food item
# 2. View food item by ID
# 3. Edit food item by ID
# ...
